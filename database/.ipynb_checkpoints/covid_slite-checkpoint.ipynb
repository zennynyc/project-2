# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "confirmed_us_daily.csv"
covid_df = pd.read_csv(csv_file)
covid_df.head(50)
# Out:
#                        state code      lat      long    total  1/22/20  \
# 0              United States  NaN      NaN       NaN  3117946        1
# 1                    Alabama   AL  32.3182  -86.9023    49174        0
# 2                     Alaska   AK  61.3707 -152.4044     1268        0
# 3                    Arizona   AZ  33.7298 -111.4312   112671        0
# 4                   Arkansas   AR  34.9697  -92.3731    26052        0
# 5                 California   CA  36.1162 -119.6816   302484        0
# 6                   Colorado   CO  39.0598 -105.3111    35507        0
# 7                Connecticut   CT  41.5978  -72.7554    47209        0
# 8                   Delaware   DE  39.3185  -75.5071    12531        0
# 9       District of Columbia  NaN  38.8974  -77.0268    10679        0
# 10                   Florida   FL  27.7663  -81.6868   232718        0
# 11                   Georgia   GA  33.0406  -83.6431   106727        0
# ...

# %%
covid_df.drop([0]).head()
newcovid_df= covid_df.drop([0])
newcovid_df
# Out:
#                        state code      lat      long   total  1/22/20  \
# 1                    Alabama   AL  32.3182  -86.9023   49174        0
# 2                     Alaska   AK  61.3707 -152.4044    1268        0
# 3                    Arizona   AZ  33.7298 -111.4312  112671        0
# 4                   Arkansas   AR  34.9697  -92.3731   26052        0
# 5                 California   CA  36.1162 -119.6816  302484        0
# 6                   Colorado   CO  39.0598 -105.3111   35507        0
# 7                Connecticut   CT  41.5978  -72.7554   47209        0
# 8                   Delaware   DE  39.3185  -75.5071   12531        0
# 9       District of Columbia  NaN  38.8974  -77.0268   10679        0
# 10                   Florida   FL  27.7663  -81.6868  232718        0
# 11                   Georgia   GA  33.0406  -83.6431  106727        0
# 12                      Guam  NaN  13.4443  144.7937     309        0
# ...

# %%
connection_string = "postgres:Alake1991@localhost:5432/covidwebsite_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['covid_website']

# %%
newcovid_df.to_sql(name='covid_website', con=engine, if_exists='append', index=False)
